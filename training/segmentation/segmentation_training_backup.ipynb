# %% [markdown]
# # 🚀 YOLOv8 Segmentação - Treinamento
#
# **Instruções:**
# 1. Copie seu dataset (estrutura: images/train, labels/train, data.yaml) para a pasta `dataset/`
# 2. Execute as células em ordem

# %%
from ultralytics import YOLO
from pathlib import Path

# Setup de diretórios
BASE_DIR = Path.cwd()
DATASET_PATH = BASE_DIR / 'dataset'

print(f"✓ Dataset path: {DATASET_PATH}")
print(f"✓ Arquivos: {list(DATASET_PATH.glob('*'))[:5]}")

# %% [markdown]
# ## 🎯 TREINAR SEGMENTAÇÃO

# %%
# Parâmetros de treinamento
MODEL = 'yolov8n-seg'        # nano, small, medium, large, xlarge
EPOCHS = 1000
BATCH_SIZE = 4
IMG_SIZE = 640
DEVICE = 0                  # 0=GPU, -1=CPU
SAVE_NAME = 'moesV2'
PATIENCE = 30
print(f"🚀 Treinando {MODEL}...")
print(f"📂 Dataset: {DATASET_PATH}")
print(f"⏰ Épocas: {EPOCHS}")
print(f"📦 Batch: {BATCH_SIZE}\n")

model = YOLO(MODEL)
results = model.train(
    data=str(DATASET_PATH / 'data.yaml'),
    epochs=EPOCHS,
    batch=BATCH_SIZE,
    imgsz=IMG_SIZE,
    device=DEVICE,
    patience=PATIENCE,
    project='runs',
    name=SAVE_NAME,
    exist_ok=False,
    single_cls=True
)

print(f"\n✅ Treinamento concluído!")
print(f"📁 Modelo: runs/{SAVE_NAME}/weights/best.pt")

# %% [markdown]
# ## 🧪 TESTAR MODELO

# %%
# # Descomente para testar
# model = YOLO('runs/fruta_seg/weights/best.pt')
# results = model.predict('dataset/images/val/image.jpg')
# results[0].show()

# %% [markdown]
# ## 🧹 LIMPEZA DE MEMÓRIA

# %%
import gc

# Limpar cache e liberar memória
try:
    del model
    print("✓ Modelo deletado")
except NameError:
    print("ℹ Nenhum modelo em memória")

gc.collect()
print("✓ Garbage collection executado")
