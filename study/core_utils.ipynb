# %% [markdown]
# ## Classe `SystemLogger`
# O que representa esta classe? (responda abaixo)

# %% [markdown]
# ### Método `SystemLogger.__init__`
# O que faz este método? (responda abaixo)

# %%
def __init__(self):
        self._configure_logger()

# %% [markdown]
# ### Método `SystemLogger._configure_logger`
# O que faz este método? (responda abaixo)

# %%
def _configure_logger(self):
        logger.remove()
        logger.add(sys.stdout, level=LOGGING_CONFIG['level'], format=LOGGING_CONFIG['format'], colorize=True)
        log_file = LOGS_DIR / f"system_{datetime.now().strftime('%Y%m%d')}.log"
        logger.add(str(log_file), level='DEBUG', format=LOGGING_CONFIG['format'], rotation=LOGGING_CONFIG['rotation'], retention=LOGGING_CONFIG['retention'], compression='zip')
        error_file = LOGS_DIR / 'errors.log'
        logger.add(str(error_file), level='ERROR', format=LOGGING_CONFIG['format'], rotation='50 MB', retention='1 year')
        logger.info('Sistema de logging configurado com sucesso')
        logger.info(f'Logs principais: {log_file}')
        logger.info(f'Logs de erro: {error_file}')

# %% [markdown]
# ### Método `SystemLogger.get_logger`
# O que faz este método? (responda abaixo)

# %%
def get_logger(self):
        return logger

# %% [markdown]
# ### Método `SystemLogger.info`
# O que faz este método? (responda abaixo)

# %%
def info(self, message: str):
        logger.info(message)

# %% [markdown]
# ### Método `SystemLogger.error`
# O que faz este método? (responda abaixo)

# %%
def error(self, message: str):
        logger.error(message)

# %% [markdown]
# ### Método `SystemLogger.warning`
# O que faz este método? (responda abaixo)

# %%
def warning(self, message: str):
        logger.warning(message)

# %% [markdown]
# ### Método `SystemLogger.debug`
# O que faz este método? (responda abaixo)

# %%
def debug(self, message: str):
        logger.debug(message)

# %% [markdown]
# ### Método `SystemLogger.critical`
# O que faz este método? (responda abaixo)

# %%
def critical(self, message: str):
        logger.critical(message)

# %% [markdown]
# ## 🧹 LIMPEZA DE MEMÓRIA

# %%
import gc

# Limpar cache e liberar memória
try:
    del model
    print("✓ Modelo deletado")
except NameError:
    print("ℹ Nenhum modelo em memória")

gc.collect()
print("✓ Garbage collection executado")
